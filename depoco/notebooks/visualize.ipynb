# %%
from depoco.plot_results import *
path = '../experiments/results/longdress/'
files = sorted(glob.glob(path+'*.pkl'))


for f in files:
    print(f)

f, ax = plt.subplots(2, 2)
ax = ax.flatten()
f.suptitle('LongDress Depoco Results 5000 nr-50 epoc')
genPlots(files, f, ax, draw_line=True, label='our', x_key='bpp')
for a in ax:
    a.grid()
    # a.set_ylim([0,None])
    a.legend()
plt.tight_layout()
plt.show()

path = '../experiments/results/longdress_tmc13/'
files = sorted(glob.glob(path+'*.pkl'))


for f in files:
    print(f)

f, ax = plt.subplots(2, 2)
ax = ax.flatten()
f.suptitle('LongDress Results tmc13')
genPlots(files, f, ax, draw_line=True, label='our', x_key='bpp')
for a in ax:
    a.grid()
    # a.set_ylim([0,None])
    a.legend()
plt.tight_layout()
plt.show()





path = '../experiments/results/kitti/'
files = sorted(glob.glob(path+'*.pkl'))


for f in files:
    print(f)

f, ax = plt.subplots(2, 2)
ax = ax.flatten()
f.suptitle('Kitti Results')
genPlots(files, f, ax, draw_line=True, label='our', x_key='bpp')
for a in ax:
    a.grid()
    # a.set_ylim([0,None])
    a.legend()
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ../experiments/results/longdress_tmc13/ldf_e0.pkl
# ../experiments/results/longdress_tmc13/ldf_e1.pkl
# ../experiments/results/longdress_tmc13/ldf_e2.pkl
# ../experiments/results/longdress_tmc13/ldf_e3.pkl
# ../experiments/results/longdress_tmc13/ldf_e0.pkl
# ../experiments/results/longdress_tmc13/ldf_e1.pkl
# ../experiments/results/longdress_tmc13/ldf_e2.pkl
# ../experiments/results/longdress_tmc13/ldf_e3.pkl
# ../experiments/results/longdress_tmc13/ldf_e0.pkl
# ../experiments/results/longdress_tmc13/ldf_e1.pkl
# ../experiments/results/longdress_tmc13/ldf_e2.pkl
# ../experiments/results/longdress_tmc13/ldf_e3.pkl
# ../experiments/results/longdress_tmc13/ldf_e0.pkl
# ../experiments/results/longdress_tmc13/ldf_e1.pkl
# ../experiments/results/longdress_tmc13/ldf_e2.pkl
# ../experiments/results/longdress_tmc13/ldf_e3.pkl
# ...

# %%
import numpy as np
import open3d as o3d
#print("Load a ply point cloud, print it, and render it")
#ply_point_cloud = o3d.data.PLYPointCloud()
#file_path = "/home/afz/Downloads/depoco/tmc_13/mpeg-pcc-tmc13/experiment/lossy-geom-no-attrs/head/r01/000000.ply.bin.decoded.ply"
file_path = "../experiments/recons/e3_000000_decode.ply"
pcd = o3d.io.read_point_cloud(file_path)
#print(pcd.colors)
tt = np.array([[1.41039658e+02 , 1.61005478e+02 ,-7.21966028e-02],
 [ 1.41035736e+02 , 1.60968201e+02 ,-6.27447665e-02],
 [ 1.41063721e+02 , 1.61005722e+02, -6.23855740e-02],
              [ 1.41063721e+02 , 1.61005722e+02, -6.23855740e-02]])
print(len(tt))
print(len(np.asarray(pcd.points)))
o3d.visualization.draw_geometries([pcd])
# Out:
# 4
# 1269248
